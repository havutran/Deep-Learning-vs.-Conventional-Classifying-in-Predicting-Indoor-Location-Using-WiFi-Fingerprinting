# %%
import numpy as np
import pandas as pd

import matplotlib as plt

# %%
df = pd.read_csv("challenge1.csv")

# %%
df.describe()
# Out:
#          Unnamed: 0        WAP001        WAP002   WAP003   WAP004  \
# count  19937.000000  19749.000000  19757.000000  19722.0  19722.0
# mean    9968.000000     99.821966     99.819305    100.0    100.0
# std     5755.460494      5.894677      5.824485      0.0      0.0
# min        0.000000    -97.000000    -90.000000    100.0    100.0
# 25%     4984.000000    100.000000    100.000000    100.0    100.0
# 50%     9968.000000    100.000000    100.000000    100.0    100.0
# 75%    14952.000000    100.000000    100.000000    100.0    100.0
# max    19936.000000    100.000000    100.000000    100.0    100.0
#
#              WAP005        WAP006        WAP007        WAP008        WAP009  \
# count  19760.000000  19730.000000  19731.000000  19741.000000  19728.000000
# mean      99.610273     97.129042     94.706452     93.824274     94.692062
# std        8.654083     22.935728     30.617533     32.997606     30.309669
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'WAP001', 'WAP002', 'WAP003', 'WAP004', 'WAP005',
#        'WAP006', 'WAP007', 'WAP008', 'WAP009', 'WAP010', 'WAP011',
#        'WAP012', 'WAP013', 'WAP014', 'WAP015', 'WAP016', 'WAP017',
#        'WAP018', 'WAP019', 'WAP020', 'WAP021', 'WAP022', 'WAP023',
#        'WAP024', 'WAP025', 'WAP026', 'WAP027', 'WAP028', 'WAP029',
#        'WAP030', 'WAP031', 'WAP032', 'WAP033', 'WAP034', 'WAP035',
#        'WAP036', 'WAP037', 'WAP038', 'WAP039', 'WAP040', 'WAP041',
#        'WAP042', 'WAP043', 'WAP044', 'WAP045', 'WAP046', 'WAP047',
#        'WAP048', 'WAP049', 'WAP050', 'WAP051', 'WAP052', 'WAP053',
#        'WAP054', 'WAP055', 'WAP056', 'WAP057', 'WAP058', 'WAP059',
#        'WAP060', 'WAP061', 'WAP062', 'WAP063', 'WAP064', 'WAP065',
#        'WAP066', 'WAP067', 'WAP068', 'WAP069', 'WAP070', 'WAP071',
#        'WAP072', 'WAP073', 'WAP074', 'WAP075', 'WAP076', 'WAP077',
#        'WAP078', 'WAP079', 'WAP080', 'WAP081', 'WAP082', 'WAP083',
# ...

# %%
#
df.isnull().sum()
# Out:
# Unnamed: 0      0
# WAP001        188
# WAP002        180
# WAP003        215
# WAP004        215
# WAP005        177
# WAP006        207
# WAP007        206
# WAP008        196
# WAP009        209
# WAP010        215
# WAP011        204
# WAP012        188
# WAP013        193
# WAP014        194
# WAP015        190
# WAP016        218
# WAP017        183
# WAP018        211
# WAP019        188
# WAP020        220
# WAP021        160
# WAP022        197
# WAP023        181
# WAP024        186
# WAP025        202
# WAP026        218
# WAP027        185
# WAP028        178
# WAP029        201
#              ...
# WAP498        196
# WAP499        207
# WAP500        206
# WAP501        196
# WAP502        219
# WAP503        218
# WAP504        197
# WAP505        199
# WAP506        179
# WAP507        198
# WAP508        178
# WAP509        190
# WAP510        173
# WAP511        209
# WAP512        207
# WAP513        179
# WAP514        191
# WAP515        198
# WAP516        188
# ...

# %%
df['FLOOR'].unique()
# Out:
# array(['Floor_2', 'Floor_0', 'Floor_3', nan, 'Floor_4', 'Floor_1'],
#       dtype=object)

# %%
df['BUILDINGID'].unique()
# Out:
# array([ 1.,  0.,  2., nan])

# %%
df['USERID'].unique()
# Out:
# array([ 2., 11., nan,  3.,  4.,  5.,  6.,  7.,  8.,  9., 16., 10., 12.,
#        13., 14., 15.,  1., 17., 18.])

# %%
#Convert the floor values into numbers
for i in range(len(df[df.columns[523]])):
    if df.iloc[i, 523] == 'Floor_0': df.iloc[i, 523] = round(1)
    elif df.iloc[i, 523] == 'Floor_1': df.iloc[i, 523] = round(2)
    elif df.iloc[i, 523] == 'Floor_2': df.iloc[i, 523] = round(3)
    elif df.iloc[i, 523] == 'Floor_3': df.iloc[i, 523] = round(4)
    else: df.iloc[i, 523] = int(5)

# %%
df.plot(kind="scatter", x="LONGITUDE", y="LATITUDE", alpha=0.2, figsize=(15,10),
    c="BUILDINGID", colorbar=False,
    sharex=False)

# %%
df['FLOOR'] = df['FLOOR'].astype('int64',inplace=True)


df.iloc[:, 521:528].hist(bins=50, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f416c2f75c0>,
# ...
#       dtype=object)

# %%
df.iloc[:, 523]
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        1
# 5        3
# 6        3
# 7        3
# 8        3
# 9        3
# 10       3
# 11       3
# 12       3
# 13       3
# 14       3
# 15       3
# 16       3
# 17       3
# 18       3
# 19       3
# 20       3
# 21       3
# 22       3
# 23       3
# 24       3
# 25       3
# 26       3
# 27       3
# 28       3
# 29       3
#         ..
# 19907    4
# 19908    4
# 19909    4
# 19910    2
# 19911    2
# 19912    2
# 19913    2
# 19914    2
# 19915    2
# 19916    2
# 19917    2
# 19918    2
# 19919    2
# 19920    2
# 19921    2
# 19922    2
# 19923    2
# 19924    2
# 19925    2
# 19926    2
# 19927    2
# 19928    2
# 19929    4
# 19930    4
# 19931    2
# 19932    4
# 19933    2
# 19934    4
# 19935    4
# 19936    4
# Name: FLOOR, dtype: int64
